# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %%
data_skill =pd.read_csv('messy_data.csv')
data_skill.head(4)
# Out:
#    TrnsnID        Data  CusmrID  ProdtID ProdtName  Qutity   Prize  TtlSales  \
# 0     7402  03/17/2026      991     1045     Boo E       9  167.72   2935.06
# 1     5835  26-01-2035      741     1040    Book J      18  193.27   4386.52
# 2     2123  05/26/2035      933     1062     Bok N       5  126.39   1948.46
# 3     8789  28-02-2036      641     1060    Book I       6   66.98   1757.26
#
#   PaymentType  CusterAge
# 0         NaN         87
# 1  debit card         69
# 2        Cash         15
# 3        Cash         22

# %% [markdown]
# ###### Check for  any duplicate rows

# %%
data_skill[data_skill.duplicated()]
# Out:
#       TrnsnID        Data  CusmrID  ProdtID ProdtName  Qutity   Prize  \
# 919       800  02-12-2023      480     1060    Book I       9   77.26
# 980      1057  04-10-2034      138     1086    Book T       5   94.21
# 1062     2305  12/19/2025      252     1015    Book G      17  100.39
# 1119     2593  18-04-2029      885     1094       NaN       4   62.35
# 1136     2928  12/07/2033       43     1074    Book J      11  172.68
# ...       ...         ...      ...      ...       ...     ...     ...
# 9587     8285  01/05/2036      220     1047    Book G      16  185.09
# 9598     9921  08/24/2026       84     1034    Book I       5   41.14
# 9785     5360  10/05/2028       35     1061    Book S      -4   90.41
# 9825      953  19-02-2026      587     1051       NaN      11  119.82
# 9951     8128  24-01-2035      458     1033    Book G      -2   88.56
#
#       TtlSales  PaymentType  CusterAge
# 919    2032.76          NaN         53
# 980    4352.25       Credit         61
# ...

# %% [markdown]
# ###### Check for  any duplicate column 'TrnsnID'

# %%
data_skill[data_skill['TrnsnID'].duplicated()]
# Out:
#       TrnsnID        Data  CusmrID  ProdtID ProdtName  Qutity   Prize  \
# 919       800  02-12-2023      480     1060    Book I       9   77.26
# 980      1057  04-10-2034      138     1086    Book T       5   94.21
# 1062     2305  12/19/2025      252     1015    Book G      17  100.39
# 1119     2593  18-04-2029      885     1094       NaN       4   62.35
# 1136     2928  12/07/2033       43     1074    Book J      11  172.68
# ...       ...         ...      ...      ...       ...     ...     ...
# 9587     8285  01/05/2036      220     1047    Book G      16  185.09
# 9598     9921  08/24/2026       84     1034    Book I       5   41.14
# 9785     5360  10/05/2028       35     1061    Book S      -4   90.41
# 9825      953  19-02-2026      587     1051       NaN      11  119.82
# 9951     8128  24-01-2035      458     1033    Book G      -2   88.56
#
#       TtlSales  PaymentType  CusterAge
# 919    2032.76          NaN         53
# 980    4352.25       Credit         61
# ...

# %% [markdown]
#  ### Remove any duplicate rows

# %%
data_skill.drop_duplicates(inplace=True)
data_skill
# Out:
#        TrnsnID        Data  CusmrID  ProdtID ProdtName  Qutity   Prize  \
# 0         7402  03/17/2026      991     1045     Boo E       9  167.72
# 1         5835  26-01-2035      741     1040    Book J      18  193.27
# 2         2123  05/26/2035      933     1062     Bok N       5  126.39
# 3         8789  28-02-2036      641     1060    Book I       6   66.98
# 4          305  19-04-2023      123     1058    Book B      15   33.63
# ...        ...         ...      ...      ...       ...     ...     ...
# 10095     5735  04/03/2027       52     1066    Book G       1  191.41
# 10096     5192  08/16/2025      334     1093     Bok N      -2  186.16
# 10097     5391  06/18/2026      657     1047   Bookk H       5   84.38
# 10098      861  04/08/2034      579     1014     Bok N      19  137.58
# 10099     7271  26-04-2029      153     1052    Book T      10  159.98
#
#        TtlSales  PaymentType  CusterAge
# 0       2935.06          NaN         87
# ...

# %% [markdown]
# #### Check out for Missing Values

# %%
data_skill.isnull().sum()
# Out:
# TrnsnID           0
# Data              0
# CusmrID           0
# ProdtID           0
# ProdtName       994
# Qutity            0
# Prize             0
# TtlSales          0
# PaymentType    1439
# CusterAge         0
# dtype: int64

# %% [markdown]
# #### Ensure all dates are in a consistent format

# %%
#data_skill[(data_skill['PaymentType'] ==  'Data').isnull()]

# %%
data_skill['Data'] = pd.to_datetime(data_skill['Data']);
data_skill['Data'];

# %%
plt.plot(data_skill['Data'], data_skill['TtlSales'])
plt.show()

# %% [markdown]
# #### Standardize the product type names.

# %%
data_skill[['ProdtName']].value_counts()
# Out:
# ProdtName
# Boo E        565
# Book O       547
# Book I       523
# Book M       522
# Book L       513
# Book D       510
# Book J       504
# Book R       500
# Book P       500
# Book S       499
# Book K       495
# Book T       492
# Bookk H      489
# Book G       489
# Bok N        486
# Book F       480
# Book A       448
# Book B       444
# dtype: int64

# %%
data_skill['ProdtName'].replace('Boo E', 'Book E', inplace = True)
data_skill['ProdtName'].replace('Bok N', 'Book N', inplace =True)
data_skill['ProdtName'].replace('Bookk H', 'Book H', inplace =True)

# %%
data_skill[['ProdtName']].value_counts()
# Out:
# ProdtName
# Book E       565
# Book O       547
# Book I       523
# Book M       522
# Book L       513
# Book D       510
# Book J       504
# Book R       500
# Book P       500
# Book S       499
# Book K       495
# Book T       492
# Book H       489
# Book G       489
# Book N       486
# Book F       480
# Book A       448
# Book B       444
# dtype: int64

# %% [markdown]
# #### Standardize the payment type names

# %%
data_skill.groupby(['PaymentType']).size()
# Out:
# PaymentType
# Cash           1426
# Credit         1433
# Credit Card    1419
# Debit          1452
# debit card     1417
# paypal         1414
# dtype: int64

# %%
data_skill['PaymentType'].replace('Credit Card', 'Credit', inplace = True)
data_skill['PaymentType'].replace('debit card', 'Debit', inplace = True)

# %%
#data_skill['PaymentType'] = data_skill['PaymentType'].str.replace('Credit', 'C')

# %%
data_skill.groupby(['PaymentType']).size()
# Out:
# PaymentType
# Cash      1426
# Credit    2852
# Debit     2869
# paypal    1414
# dtype: int64

# %% [markdown]
# #### Negative Values: Look for negative values in columns where it doesn't make sense

# %%
sns.displot(data_skill)

# %%
#data_skill.where(data_skill <0 )

# %% [markdown]
# #### Data Types: Ensure each column is of the right data

# %%
data_skill.isnull().sum()
# Out:
# TrnsnID           0
# Data              0
# CusmrID           0
# ProdtID           0
# ProdtName       994
# Qutity            0
# Prize             0
# TtlSales          0
# PaymentType    1439
# CusterAge         0
# dtype: int64

# %%
data_skill.dtypes
# Out:
# TrnsnID                 int64
# Data           datetime64[ns]
# CusmrID                 int64
# ProdtID                 int64
# ProdtName              object
# Qutity                  int64
# Prize                 float64
# TtlSales              float64
# PaymentType            object
# CusterAge               int64
# dtype: object

# %% [markdown]
# #### Lastly : Correct the entire columns name that are spelt wrongly (TransactionID, Date, CustomerID, ProductID, ProductName, Quantity, Price, TotalSales, PaymentType,  CustomerAge)

# %%
 data_skill = data_skill.rename(columns = {
     'TrnsnID': 'TransactionID',
    'CusmrID':  'CustomerID',
    'ProdtID': 'ProductID',             
    'ProdtName':'ProductName',        
    'Qutity': 'Quantity',
    'Prize': 'Price',
    'TtlSales':'TotalSales',         
    'PaymentType':'PaymentType',         
    'CusterAge': 'CustomerAge'
     })

# %%
data_skill.head()
# Out:
#    TransactionID       Data  CustomerID  ProductID ProductName  Quantity  \
# 0           7402 2026-03-17         991       1045      Book E         9
# 1           5835 2035-01-26         741       1040      Book J        18
# 2           2123 2035-05-26         933       1062      Book N         5
# 3           8789 2036-02-28         641       1060      Book I         6
# 4            305 2023-04-19         123       1058      Book B        15
#
#     Price  TotalSales PaymentType  CustomerAge
# 0  167.72     2935.06         NaN           87
# 1  193.27     4386.52       Debit           69
# 2  126.39     1948.46        Cash           15
# 3   66.98     1757.26        Cash           22
# 4   33.63     2578.19        Cash           -1
